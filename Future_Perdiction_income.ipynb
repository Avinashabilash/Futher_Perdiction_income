# %% [markdown]
# # INSTALL LIBRARY

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\abiav\appdata\local\programs\python\python310\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\abiav\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abiav\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abiav\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abiav\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\abiav\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -eras (c:\users\abiav\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\abiav\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\abiav\appdata\local\programs\python\python310\lib\site-packages)

# %%
import numpy
import pandas as pd
from sklearn import linear_model 
import matplotlib.pyplot as plt

# %% [markdown]
# # LOAD DATA SET

# %%
df=pd.read_csv(r"C:\Users\abiav\Find future income\canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %% [markdown]
# # PLOT THE GRAPH

# %%
# %matplotlib inline
plt.xlabel("year('era')")
plt.ylabel("per capita income('US$')")
plt.scatter(df["year"],df["per capita income (US$)"],color ="red",marker = ",")

# %%
print(df.columns)
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %% [markdown]
# # THE COLOUMN OF LINEAR REGRESSION

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression()
reg.fit(df[["year"]], df["per capita income (US$)"])
# Out:
# LinearRegression()

# %% [markdown]
# # FINAL PERDICTION

# %%
print(reg.predict([[2020]]))
# Out:
# [41288.69409442]
# C:\Users\abiav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
